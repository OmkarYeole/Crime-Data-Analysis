# %% [markdown]
# ## Model Training

# %% [markdown]
# ##### Importing Libraries

# %%
# Basic Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# Feature Transformation
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler, OrdinalEncoder,OneHotEncoder
from sklearn.compose import ColumnTransformer

# Modelling
from sklearn.metrics import accuracy_score, f1_score
from catboost import CatBoostClassifier
from sklearn.ensemble import (
    AdaBoostClassifier,
    GradientBoostingClassifier,
    RandomForestClassifier,
)
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
import warnings

# %%
df = pd.read_csv('crime.csv', encoding='latin-1')

# %%
df = df.head(10000)
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0      D14            808      NaN  2018-09-02 13:00:00  2018      9
# 1      C11            347      NaN  2018-08-21 00:00:00  2018      8
# 2       D4            151      NaN  2018-09-03 19:27:00  2018      9
# 3       D4            272      NaN  2018-09-03 21:16:00  2018      9
# 4       B3            421      NaN  2018-09-03 21:05:00  2018      9
#
#   DAY_OF_WEEK  HOUR    UCR_PART       STREET        Lat       Long  \
# 0      Sunday    13    Part One   LINCOLN ST  42.357791 -71.139371
# 1     Tuesday     0    Part Two     HECLA ST  42.306821 -71.060300
# 2      Monday    19  Part Three  CAZENOVE ST  42.346589 -71.072429
# 3      Monday    21  Part Three   NEWCOMB ST  42.334182 -71.078664
# 4      Monday    21  Part Three     DELHI ST  42.275365 -71.090361
#
#                       Location
# 0  (42.35779134, -71.13937053)
# 1  (42.30682138, -71.06030035)
# 2  (42.34658879, -71.07242943)
# 3  (42.33418175, -71.07866441)
# 4  (42.27536542, -71.09036101)

# %% [markdown]
# ##### Preparing X and Y variables

# %%
df = df.drop(columns=['INCIDENT_NUMBER'], axis=1)

# %%
df['OCCURRED_ON_DATE'] = pd.to_datetime(df['OCCURRED_ON_DATE'])
print(df['OCCURRED_ON_DATE'].dtype)
# Out:
# datetime64[ns]

# %%
# Extract date features
df['YEAR'] = df['OCCURRED_ON_DATE'].dt.year
df['MONTH'] = df['OCCURRED_ON_DATE'].dt.month
df['DAY'] = df['OCCURRED_ON_DATE'].dt.day
df['HOUR'] = df['OCCURRED_ON_DATE'].dt.hour

# %%
df.head()
# Out:
#    OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION DISTRICT  \
# 0           619               Larceny    LARCENY ALL OTHERS      D14
# 1          1402             Vandalism             VANDALISM      C11
# 2          3410                 Towed   TOWED MOTOR VEHICLE       D4
# 3          3114  Investigate Property  INVESTIGATE PROPERTY       D4
# 4          3114  Investigate Property  INVESTIGATE PROPERTY       B3
#
#   REPORTING_AREA SHOOTING    OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# 0            808      NaN 2018-09-02 13:00:00  2018      9      Sunday    13
# 1            347      NaN 2018-08-21 00:00:00  2018      8     Tuesday     0
# 2            151      NaN 2018-09-03 19:27:00  2018      9      Monday    19
# 3            272      NaN 2018-09-03 21:16:00  2018      9      Monday    21
# 4            421      NaN 2018-09-03 21:05:00  2018      9      Monday    21
#
#      UCR_PART       STREET        Lat       Long                     Location  \
# 0    Part One   LINCOLN ST  42.357791 -71.139371  (42.35779134, -71.13937053)
# 1    Part Two     HECLA ST  42.306821 -71.060300  (42.30682138, -71.06030035)
# 2  Part Three  CAZENOVE ST  42.346589 -71.072429  (42.34658879, -71.07242943)
# 3  Part Three   NEWCOMB ST  42.334182 -71.078664  (42.33418175, -71.07866441)
# 4  Part Three     DELHI ST  42.275365 -71.090361  (42.27536542, -71.09036101)
#
#    DAY
# 0    2
# 1   21
# 2    3
# 3    3
# 4    3

# %%
# Transform location data into latitude and longitude features
df['LATITUDE'] = df['Location'].str.extract(r'\(([-+]?[0-9]*\.?[0-9]+),\s*([-+]?[0-9]*\.?[0-9]+)\)')[0].astype(float)
df['LONGITUDE'] = df['Location'].str.extract(r'\(([-+]?[0-9]*\.?[0-9]+),\s*([-+]?[0-9]*\.?[0-9]+)\)')[1].astype(float)

# %%
df.drop(columns=['Location', 'Lat', 'Long'], axis=1, inplace=True)
df.head()
# Out:
#    OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION DISTRICT  \
# 0           619               Larceny    LARCENY ALL OTHERS      D14
# 1          1402             Vandalism             VANDALISM      C11
# 2          3410                 Towed   TOWED MOTOR VEHICLE       D4
# 3          3114  Investigate Property  INVESTIGATE PROPERTY       D4
# 4          3114  Investigate Property  INVESTIGATE PROPERTY       B3
#
#   REPORTING_AREA SHOOTING    OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# 0            808      NaN 2018-09-02 13:00:00  2018      9      Sunday    13
# 1            347      NaN 2018-08-21 00:00:00  2018      8     Tuesday     0
# 2            151      NaN 2018-09-03 19:27:00  2018      9      Monday    19
# 3            272      NaN 2018-09-03 21:16:00  2018      9      Monday    21
# 4            421      NaN 2018-09-03 21:05:00  2018      9      Monday    21
#
#      UCR_PART       STREET  DAY   LATITUDE  LONGITUDE
# 0    Part One   LINCOLN ST    2  42.357791 -71.139371
# 1    Part Two     HECLA ST   21  42.306821 -71.060300
# 2  Part Three  CAZENOVE ST    3  42.346589 -71.072429
# 3  Part Three   NEWCOMB ST    3  42.334182 -71.078664
# 4  Part Three     DELHI ST    3  42.275365 -71.090361

# %%
# Split the REPORTING_AREA feature into numeric and non-numeric components
df['REPORTING_AREA'] = df['REPORTING_AREA'].str.extract(r'(\d+)')[0].astype(float)
df['REPORTING_AREA_STR'] = df['REPORTING_AREA'].astype(str)
df.drop('REPORTING_AREA', axis=1, inplace=True)

# %%
df.head()
# Out:
#    OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION DISTRICT SHOOTING  \
# 0           619               Larceny    LARCENY ALL OTHERS      D14      NaN
# 1          1402             Vandalism             VANDALISM      C11      NaN
# 2          3410                 Towed   TOWED MOTOR VEHICLE       D4      NaN
# 3          3114  Investigate Property  INVESTIGATE PROPERTY       D4      NaN
# 4          3114  Investigate Property  INVESTIGATE PROPERTY       B3      NaN
#
#      OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART       STREET  \
# 0 2018-09-02 13:00:00  2018      9      Sunday    13    Part One   LINCOLN ST
# 1 2018-08-21 00:00:00  2018      8     Tuesday     0    Part Two     HECLA ST
# 2 2018-09-03 19:27:00  2018      9      Monday    19  Part Three  CAZENOVE ST
# 3 2018-09-03 21:16:00  2018      9      Monday    21  Part Three   NEWCOMB ST
# 4 2018-09-03 21:05:00  2018      9      Monday    21  Part Three     DELHI ST
#
#    DAY   LATITUDE  LONGITUDE REPORTING_AREA_STR
# 0    2  42.357791 -71.139371              808.0
# 1   21  42.306821 -71.060300              347.0
# 2    3  42.346589 -71.072429              151.0
# 3    3  42.334182 -71.078664              272.0
# 4    3  42.275365 -71.090361              421.0

# %%
df.drop(columns=['OFFENSE_DESCRIPTION', 'OCCURRED_ON_DATE'], axis=1,inplace=True)
df.head()
# Out:
#    OFFENSE_CODE    OFFENSE_CODE_GROUP DISTRICT SHOOTING  YEAR  MONTH  \
# 0           619               Larceny      D14      NaN  2018      9
# 1          1402             Vandalism      C11      NaN  2018      8
# 2          3410                 Towed       D4      NaN  2018      9
# 3          3114  Investigate Property       D4      NaN  2018      9
# 4          3114  Investigate Property       B3      NaN  2018      9
#
#   DAY_OF_WEEK  HOUR    UCR_PART       STREET  DAY   LATITUDE  LONGITUDE  \
# 0      Sunday    13    Part One   LINCOLN ST    2  42.357791 -71.139371
# 1     Tuesday     0    Part Two     HECLA ST   21  42.306821 -71.060300
# 2      Monday    19  Part Three  CAZENOVE ST    3  42.346589 -71.072429
# 3      Monday    21  Part Three   NEWCOMB ST    3  42.334182 -71.078664
# 4      Monday    21  Part Three     DELHI ST    3  42.275365 -71.090361
#
#   REPORTING_AREA_STR
# 0              808.0
# 1              347.0
# 2              151.0
# 3              272.0
# 4              421.0

# %%
df.isna().sum()
# Out:
# OFFENSE_CODE             0
# OFFENSE_CODE_GROUP       0
# DISTRICT               165
# SHOOTING              9977
# YEAR                     0
# MONTH                    0
# DAY_OF_WEEK              0
# HOUR                     0
# UCR_PART                 2
# STREET                 227
# DAY                      0
# LATITUDE                 0
# LONGITUDE                0
# REPORTING_AREA_STR       0
# dtype: int64

# %%
df['REPORTING_AREA_STR'].dtype
# Out:
# dtype('O')

# %%
len(df.columns)
# Out:
# 14

# %%
df.head()
# Out:
#    OFFENSE_CODE    OFFENSE_CODE_GROUP DISTRICT SHOOTING  YEAR  MONTH  \
# 0           619               Larceny      D14      NaN  2018      9
# 1          1402             Vandalism      C11      NaN  2018      8
# 2          3410                 Towed       D4      NaN  2018      9
# 3          3114  Investigate Property       D4      NaN  2018      9
# 4          3114  Investigate Property       B3      NaN  2018      9
#
#   DAY_OF_WEEK  HOUR    UCR_PART       STREET  DAY   LATITUDE  LONGITUDE  \
# 0      Sunday    13    Part One   LINCOLN ST    2  42.357791 -71.139371
# 1     Tuesday     0    Part Two     HECLA ST   21  42.306821 -71.060300
# 2      Monday    19  Part Three  CAZENOVE ST    3  42.346589 -71.072429
# 3      Monday    21  Part Three   NEWCOMB ST    3  42.334182 -71.078664
# 4      Monday    21  Part Three     DELHI ST    3  42.275365 -71.090361
#
#   REPORTING_AREA_STR
# 0              808.0
# 1              347.0
# 2              151.0
# 3              272.0
# 4              421.0

# %%
# Define categorical and numeric features
categorical_columns = ['DAY_OF_WEEK', 'DISTRICT', 'UCR_PART', 'STREET','DAY_OF_WEEK','REPORTING_AREA_STR']
numerical_columns = ['LATITUDE', 'LONGITUDE', 'YEAR', 'MONTH', 'DAY', 'HOUR']

# Define preprocessing steps for categorical features
cat_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("ordinal_encoder", OrdinalEncoder()),
        ("scaler", StandardScaler(with_mean=False))
    ]
)

# Define preprocessing steps for numeric features
num_transformer = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='mean')),
        ('standard_scaler', StandardScaler())
    ]
)

# Define column transformer to apply preprocessing steps to each feature type
preprocessor = ColumnTransformer(transformers=[
    ('num_pipeline', num_transformer, numerical_columns),
    ('cat_pipeline', cat_transformer, categorical_columns)
])

# Extract target variable
target_variable = df['OFFENSE_CODE_GROUP']
# Drop target variable from the DataFrame
df = df.drop(columns=['OFFENSE_CODE_GROUP'])

# Apply preprocessing steps to remaining features
X = preprocessor.fit_transform(df)

# Your preprocessed data is now in the variable X and your target variable is in target_variable

# %%
label_encoder = LabelEncoder()
target_variable = label_encoder.fit_transform(target_variable)
target_variable
# Out:
# array([27, 54, 53, ..., 27, 27,  0])

# %%
# separate dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,target_variable,test_size=0.2,random_state=42)
X_train.shape, X_test.shape
# Out:
# ((8000, 12), (2000, 12))

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, f1_score
def evaluate_models(X_train, y_train, X_test, y_test, models, param, scoring_function):
    scoring = make_scorer(scoring_function, average='weighted')
    report = {}

    for name, model in models.items():
        gs = GridSearchCV(model, param[name], cv=3, scoring=scoring, n_jobs=-1, verbose=3, return_train_score=True, refit=True, error_score='raise', pre_dispatch='2*n_jobs')
        gs.fit(X_train, y_train)
        best_model = gs.best_estimator_
        best_model.fit(X_train, y_train)
        y_pred = best_model.predict(X_test)
        score = scoring_function(y_test, y_pred)
        report[name] = score

    return report

# %%
models = {
                "Random Forest": RandomForestClassifier(),
                "Decision Tree": DecisionTreeClassifier(),
                "Gradient Boosting": GradientBoostingClassifier(),
                "Logistic Regression": LogisticRegression(),
                "XGBClassifier": XGBClassifier(),
                "CatBoosting Classifier": CatBoostClassifier(verbose=False),
                "AdaBoost Classifier": AdaBoostClassifier(),
            }

params={
    "Decision Tree": {
        'criterion':['gini', 'entropy']
    },
    "Random Forest":{
        'n_estimators': [8,16,32,64,128,256]
    },
    "Gradient Boosting":{
        'learning_rate':[.1,.01,.05,.001]
    },
    "Logistic Regression":{
        'C': [0.01, 0.1, 1, 10]
    },
    "XGBClassifier":{
        'learning_rate':[.1,.01,.05,.001],
    },
    "CatBoosting Classifier":{
        'depth': [6,8,10]
    },
    "AdaBoost Classifier":{
        'learning_rate':[.1,.01,0.5,.001]
    }   
}

model_report:dict=evaluate_models(
    X_train=X_train, 
    y_train=y_train, 
    X_test=X_test, 
    y_test=y_test,
    models=models,
    param=params,
    scoring_function=f1_score
    )
            
## To get best model score from dict
best_model_score = max(sorted(model_report.values()))

## To get best model name from dict
best_model_name = list(model_report.keys())[
    list(model_report.values()).index(best_model_score)
]
best_model = models[best_model_name]

print(f"Best model is {best_model} and the score is {best_model_score} ")
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# /Users/rishikeshsolapure/Desktop/Crime-Data-Analysis/cda/lib/python3.9/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# [CV 1/3] END n_estimators=8;, score=(train=0.956, test=0.238) total time=   0.2s
# [CV 2/3] END n_estimators=8;, score=(train=0.957, test=0.237) total time=   0.2s
# [CV 3/3] END n_estimators=8;, score=(train=0.957, test=0.252) total time=   0.2s
# [CV 1/3] END n_estimators=16;, score=(train=0.973, test=0.252) total time=   0.4s
# [CV 3/3] END n_estimators=16;, score=(train=0.976, test=0.257) total time=   0.4s
# [CV 2/3] END n_estimators=16;, score=(train=0.977, test=0.253) total time=   0.3s
# [CV 2/3] END n_estimators=32;, score=(train=0.979, test=0.256) total time=   0.7s
# [CV 1/3] END n_estimators=32;, score=(train=0.977, test=0.260) total time=   0.8s
# [CV 3/3] END n_estimators=32;, score=(train=0.978, test=0.268) total time=   0.7s
# [CV 2/3] END n_estimators=64;, score=(train=0.979, test=0.267) total time=   1.3s
# [CV 1/3] END n_estimators=64;, score=(train=0.977, test=0.265) total time=   1.4s
# [CV 3/3] END n_estimators=64;, score=(train=0.978, test=0.273) total time=   1.3s
# [CV 1/3] END n_estimators=128;, score=(train=0.977, test=0.265) total time=   2.5s
# [CV 2/3] END n_estimators=128;, score=(train=0.979, test=0.266) total time=   2.4s
# [CV 3/3] END n_estimators=128;, score=(train=0.978, test=0.279) total time=   2.2s
# [CV 2/3] END n_estimators=256;, score=(train=0.979, test=0.265) total time=   3.6s
# [CV 1/3] END n_estimators=256;, score=(train=0.977, test=0.272) total time=   3.7s
# [CV 3/3] END n_estimators=256;, score=(train=0.978, test=0.278) total time=   3.3s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 35
#       1 models = {
#       2                 "Random Forest": RandomForestClassifier(),
#       3                 "Decision Tree": DecisionTreeClassifier(),
#    (...)
#       8                 "AdaBoost Classifier": AdaBoostClassifier(),
#       9             }
#      11 params={
#      12     "Decision Tree": {
#      13         'criterion':['gini', 'entropy']
#    (...)
#      32     }
#      33 }
# ---> 35 model_report:dict=evaluate_models(
#      36     X_train=X_train,
#      37     y_train=y_train,
#      38     X_test=X_test,
#      39     y_test=y_test,
#      40     models=models,
#      41     param=params,
#      42     scoring_function=f1_score
#      43     )
#      45 ## To get best model score from dict
#      46 best_model_score = max(sorted(model_report.values()))
#
# Cell In[20], line 13, in evaluate_models(X_train, y_train, X_test, y_test, models, param, scoring_function)
#      11     best_model.fit(X_train, y_train)
#      12     y_pred = best_model.predict(X_test)
# ---> 13     score = scoring_function(y_test, y_pred)
#      14     report[name] = score
#      16 return report
#
# File ~/Desktop/Crime-Data-Analysis/cda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1146, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1011 def f1_score(
#    1012     y_true,
#    1013     y_pred,
#    (...)
#    1019     zero_division="warn",
#    1020 ):
#    1021     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1022
#    1023     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1144     array([0.66666667, 1.        , 0.66666667])
#    1145     """
# -> 1146     return fbeta_score(
#    1147         y_true,
#    1148         y_pred,
#    1149         beta=1,
#    1150         labels=labels,
#    1151         pos_label=pos_label,
#    1152         average=average,
#    1153         sample_weight=sample_weight,
#    1154         zero_division=zero_division,
#    1155     )
#
# File ~/Desktop/Crime-Data-Analysis/cda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1287, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1158 def fbeta_score(
#    1159     y_true,
#    1160     y_pred,
#    (...)
#    1167     zero_division="warn",
#    1168 ):
#    1169     """Compute the F-beta score.
#    1170
#    1171     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1284     array([0.71..., 0.        , 0.        ])
#    1285     """
# -> 1287     _, _, f, _ = precision_recall_fscore_support(
#    1288         y_true,
#    1289         y_pred,
#    1290         beta=beta,
#    1291         labels=labels,
#    1292         pos_label=pos_label,
#    1293         average=average,
#    1294         warn_for=("f-score",),
#    1295         sample_weight=sample_weight,
#    1296         zero_division=zero_division,
#    1297     )
#    1298     return f
#
# File ~/Desktop/Crime-Data-Analysis/cda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1573, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1571 if beta < 0:
#    1572     raise ValueError("beta should be >=0 in the F-beta score")
# -> 1573 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1575 # Calculate tp_sum, pred_sum, true_sum ###
#    1576 samplewise = average == "samples"
#
# File ~/Desktop/Crime-Data-Analysis/cda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1391, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1389         if y_type == "multiclass":
#    1390             average_options.remove("samples")
# -> 1391         raise ValueError(
#    1392             "Target is %s but average='binary'. Please "
#    1393             "choose another average setting, one of %r." % (y_type, average_options)
#    1394         )
#    1395 elif pos_label not in (None, 1):
#    1396     warnings.warn(
#    1397         "Note that pos_label (set to %r) is ignored when "
#    1398         "average != 'binary' (got %r). You may use "
#    (...)
#    1401         UserWarning,
#    1402     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
